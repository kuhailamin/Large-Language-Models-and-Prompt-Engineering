# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

# Load a RoBERTa model fine-tuned for NER
MODEL_NAME = "Jean-Baptiste/roberta-large-ner-english"

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForTokenClassification.from_pretrained(MODEL_NAME)

# Create NER pipeline
ner_pipeline = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple")

# Define a sample input
text = "Elon Musk is the CEO of Tesla, which is headquartered in Palo Alto, California."

# Perform NER
entities = ner_pipeline(text)

# Display the results
for entity in entities:
    print(f"Entity: {entity['word']}, Type: {entity['entity_group']}, Score: {entity['score']:.4f}")
# Out:
# Device set to use cpu
# Entity:  Elon Musk, Type: PER, Score: 0.9995
# Entity:  Tesla, Type: ORG, Score: 0.9953
# Entity:  Palo Alto, Type: LOC, Score: 0.9965
# Entity:  California, Type: LOC, Score: 0.9999
